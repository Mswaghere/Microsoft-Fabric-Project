# %%
df = spark.sql("SELECT * FROM Bing_lake.dbo.latest_news_db")
display(df)
# Out:
# StatementMeta(, 24f12281-70c4-4ded-b6ec-10ab2753c369, 4, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 0e09c6df-0e2d-4c45-99eb-85da80317138)

# %%
import synapse.ml.core
from synapse.ml.services import AnalyzeText
# Out:
# StatementMeta(, , , Cancelled, , Cancelled)

# %%
model = (AnalyzeText ()
        .setTextCol("description")
        .setKind("SentimentAnalysis")
        .setOutputCol("response")
        .setErrorCol("error"))
# Out:
# StatementMeta(, , , Cancelled, , Cancelled)

# %%
result = model.transform(df)
# Out:
# StatementMeta(, , , Cancelled, , Cancelled)

# %%
display(result)
# Out:
# StatementMeta(, , , Cancelled, , Cancelled)

# %%
from pyspark.sql.functions import col
sentiment_df = result.withColumn("sentiment", col("response.documents.sentiment"))
# Out:
# StatementMeta(, , , Cancelled, , Cancelled)

# %%
sentiment_df_final = sentiment_df.drop("error", "response")
# Out:
# StatementMeta(, , , Cancelled, , Cancelled)

# %%
display(sentiment_df_final)
# Out:
# StatementMeta(, , , Cancelled, , Cancelled)

# %%
sentiment_df_final.write.format("delta").mode("overwrite").saveAsTable("sentiment_Analysis")
# Out:
# StatementMeta(, , , Cancelled, , Cancelled)
